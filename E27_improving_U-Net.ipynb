# %% [markdown]
# # 27-6. 프로젝트: U-Net 성능 개선해 보기

# %%
# 필요 라이브러리 로딩
from __future__ import absolute_import, division
from __future__ import print_function, unicode_literals

import os
import time
import shutil
import functools

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.figsize'] = (12,12)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.image as mpimg
import pandas as pd
from PIL import Image
from IPython.display import clear_output

import tensorflow as tf
import tensorflow_addons as tfa
print(tf.__version__)

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
# Out:
# 2.2.0

# %% [markdown]
# ## Step1. 데이터셋 구성

# %% [markdown]
# ### 1-1 데이터 불러오기

# %%
DATASET_PATH=os.path.join(os.getenv('HOME'),'aiffel/medical')
img_dir = os.path.join(DATASET_PATH, "train")
label_dir = os.path.join(DATASET_PATH, "train_labels")

# %%
x_train_filenames = [os.path.join(img_dir, filename) for filename in os.listdir(img_dir)]
x_train_filenames.sort()
y_train_filenames = [os.path.join(label_dir, filename) for filename in os.listdir(label_dir)]
y_train_filenames.sort()

# %%
x_train_filenames, x_test_filenames, y_train_filenames, y_test_filenames = \
                    train_test_split(x_train_filenames, y_train_filenames, test_size=0.2)


num_train_examples = len(x_train_filenames)
num_test_examples = len(x_test_filenames)

print("Number of training examples: {}".format(num_train_examples))
print("Number of test examples: {}".format(num_test_examples))
# Out:
# Number of training examples: 480
# Number of test examples: 120

# %%
display_num = 5

r_choices = np.random.choice(num_train_examples, display_num)

plt.figure(figsize=(10, 15))
for i in range(0, display_num * 2, 2):
    img_num = r_choices[i // 2]
    x_pathname = x_train_filenames[img_num]
    y_pathname = y_train_filenames[img_num]

    plt.subplot(display_num, 2, i + 1)
    plt.imshow(Image.open(x_pathname))
    plt.title("Original Image")

    example_labels = Image.open(y_pathname)
    label_vals = np.unique(example_labels)

    plt.subplot(display_num, 2, i + 2)
    plt.imshow(example_labels)
    plt.title("Masked Image")
    
plt.suptitle("Examples of Images and their Masks")
plt.show()

# %% [markdown]
# ### Data augmentation

# %%
# Set hyperparameters

image_size = 256
img_shape = (image_size, image_size, 3)
batch_size = 2
max_epochs = 50

# %%
def _process_pathnames(fname, label_path):
    # We map this function onto each pathname pair
    img_str = tf.io.read_file(fname)
    img = tf.image.decode_bmp(img_str, channels=3) # RGB

    label_img_str = tf.io.read_file(label_path)
    label_img = tf.image.decode_bmp(label_img_str, channels=1) # BMP 0,1

    resize = [image_size, image_size]
    img = tf.image.resize(img, resize)
    label_img = tf.image.resize(label_img, resize)

    scale = 1 / 255.
    img = tf.cast(img, dtype=tf.float32) * scale
    label_img = tf.cast(label_img, dtype=tf.float32) * scale

    return img, label_img

# %%
def shift_img(output_img, label_img, width_shift_range, height_shift_range):
    """This fn will perform the horizontal or vertical shift"""
    if width_shift_range or height_shift_range:
        if width_shift_range:
                width_shift_range = tf.random.uniform([],
                                                  -width_shift_range * img_shape[1],
                                                  width_shift_range * img_shape[1])
        if height_shift_range:
                height_shift_range = tf.random.uniform([],
                                                   -height_shift_range * img_shape[0],
                                                   height_shift_range * img_shape[0])
        output_img = tfa.image.translate(output_img,
                                         [width_shift_range, height_shift_range])
        label_img = tfa.image.translate(label_img,
                                        [width_shift_range, height_shift_range])
    return output_img, label_img

# %%
def flip_img(horizontal_flip, tr_img, label_img):
    if horizontal_flip:
        flip_prob = tf.random.uniform([], 0.0, 1.0)
        tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                lambda: (tr_img, label_img))
    return tr_img, label_img

# %%
def _augment(img,
             label_img,
             resize=None,  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0.,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=True,  # Random left right flip,
             width_shift_range=0.05,  # Randomly translate the image horizontally
             height_shift_range=0.05):  # Randomly translate the image vertically 
    if resize is not None:
        # Resize both images
        label_img = tf.image.resize(label_img, resize)
        img = tf.image.resize(img, resize)
  
    if hue_delta:
        img = tf.image.random_hue(img, hue_delta)
  
    img, label_img = flip_img(horizontal_flip, img, label_img)
    img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
    label_img = tf.cast(label_img, dtype=tf.float32) * scale
    img = tf.cast(img, dtype=tf.float32) * scale
    return img, label_img

# %%
def get_baseline_dataset(filenames,
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=4,
                         batch_size=batch_size,
                         is_train=True):
    num_x = len(filenames)
    # Create a dataset from the filenames and labels
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    # Map our preprocessing function to every element in our dataset, taking
    # advantage of multithreading
    dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)

    if is_train:# 학습을 진행할시에만 위에 augment를 진행합니다.
        #if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
        #  assert batch_size == 1, "Batching images must be of the same size"
        dataset = dataset.map(preproc_fn, num_parallel_calls=threads)
        dataset = dataset.shuffle(num_x * 10)

    dataset = dataset.batch(batch_size)
    return dataset

# %%
train_dataset = get_baseline_dataset(x_train_filenames, # 학습 데이터
                                     y_train_filenames) # 정답 데이터
train_dataset = train_dataset.repeat()
test_dataset = get_baseline_dataset(x_test_filenames,
                                    y_test_filenames,
                                    is_train=False)
train_dataset
# Out:
# <RepeatDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.float32)>

# %%
#데이터 확인
for images, labels in train_dataset.take(1):
    # Running next element in our graph will produce a batch of images
    plt.figure(figsize=(10, 10))
    img = images[0]

    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.subplot(1, 2, 2)
    plt.imshow(labels[0, :, :, 0])
    plt.show()

# %% [markdown]
# ## Step2. metrics & loss functions

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
## Define print function
def print_images(model):
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
def mean_iou(y_true, y_pred, num_classes=2):
    # Flatten  
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    y_true_f = tf.cast(tf.round(y_true_f), dtype=tf.int32).numpy()
    y_pred_f = tf.cast(tf.round(y_pred_f), dtype=tf.int32).numpy()

    # calculate confusion matrix
    labels = list(range(num_classes))
    current = confusion_matrix(y_true_f, y_pred_f, labels=labels)

    # compute mean iou
    intersection = np.diag(current)
    ground_truth_set = current.sum(axis=1)
    predicted_set = current.sum(axis=0)
    union = ground_truth_set + predicted_set - intersection

    IoU = intersection / union.astype(np.float32)
    return np.mean(IoU)

# %% [markdown]
# ## Step2. U-Net

# %%
class Conv(tf.keras.Model):
    def __init__(self, num_filters, kernel_size):
        super(Conv, self).__init__()
        self.conv = layers.Conv2D(num_filters, kernel_size, padding='same')
        self.bn = layers.BatchNormalization()

    def call(self, inputs, training=True):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = layers.ReLU()(x)

        return x

# %%
class ConvBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters * 2, 3)

    def call(self, inputs, training=True):
        encoder = self.conv1(inputs, training=training)
        encoder = self.conv2(encoder, training=training)

        return encoder

class ConvBlock_R(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock_R, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters, 3)

    def call(self, inputs, training=True):
        decoder = self.conv1(inputs, training=training)
        decoder = self.conv2(decoder, training=training)

        return decoder


class EncoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(num_filters)
        self.encoder_pool = layers.MaxPool2D()

    def call(self, inputs, training=True):
        encoder = self.conv_block(inputs, training=training)
        encoder_pool = self.encoder_pool(encoder)

        return encoder_pool, encoder


class DecoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(DecoderBlock, self).__init__()
        self.convT = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')
        self.bn = layers.BatchNormalization()
        self.conv_block_r = ConvBlock_R(num_filters)

    def call(self, input_tensor, concat_tensor, training=True):
        decoder = self.convT(input_tensor)            
        decoder = self.bn(decoder, training=training)
        decoder = layers.ReLU()(decoder)
        decoder = tf.concat([decoder, concat_tensor], axis=-1)
        decoder = self.conv_block_r(decoder, training=training)

        return decoder

# %%
class UNet(tf.keras.Model):
    def __init__(self):
        super(UNet, self).__init__()
        self.encoder_block1 = EncoderBlock(64)
        self.encoder_block2 = EncoderBlock(128)
        self.encoder_block3 = EncoderBlock(256)
        self.encoder_block4 = EncoderBlock(512)

        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):
        encoder1_pool, encoder1 = self.encoder_block1(inputs)
        encoder2_pool, encoder2 = self.encoder_block2(encoder1_pool)
        encoder3_pool, encoder3 = self.encoder_block3(encoder2_pool)
        encoder4_pool, encoder4 = self.encoder_block4(encoder3_pool)

        center = self.center(encoder4_pool)

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)

        outputs = self.output_conv(decoder1)

        return outputs

# %%
unet_model = UNet()

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
checkpoint_dir_unet =os.path.join(DATASET_PATH,'train_ckpt/unet_model')

# %%
unet_model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = unet_model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (2, 256, 256, 1)

# %%
unet_model.summary()
# Out:
# Model: "u_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_block (EncoderBlock) multiple                  76416
# _________________________________________________________________
# encoder_block_1 (EncoderBloc multiple                  444288
# _________________________________________________________________
# encoder_block_2 (EncoderBloc multiple                  1773312
# _________________________________________________________________
# encoder_block_3 (EncoderBloc multiple                  7085568
# _________________________________________________________________
# conv_block_4 (ConvBlock)     multiple                  28326912
# _________________________________________________________________
# decoder_block (DecoderBlock) multiple                  18882048
# _________________________________________________________________
# decoder_block_1 (DecoderBloc multiple                  3542784
# _________________________________________________________________
# decoder_block_2 (DecoderBloc multiple                  886656
# _________________________________________________________________
# decoder_block_3 (DecoderBloc multiple                  222144
# _________________________________________________________________
# conv2d_18 (Conv2D)           multiple                  65
# =================================================================
# Total params: 61,240,193
# Trainable params: 61,222,529
# Non-trainable params: 17,664
# _________________________________________________________________

# %%
if not os.path.isdir(checkpoint_dir_unet):
    os.makedirs(checkpoint_dir_unet)

cp_callback_unet = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir_unet,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay_unet = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback_unet = tf.keras.callbacks.LearningRateScheduler(cos_decay_unet, verbose=1)

# %%
history_unet = unet_model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback_unet, lr_callback_unet]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
# 240/240 [==============================] - 46s 194ms/step - loss: 0.9654 - dice_loss: 0.7216 - val_loss: 1.0326 - val_dice_loss: 0.8448 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 240/240 [==============================] - 46s 190ms/step - loss: 0.9157 - dice_loss: 0.7109 - val_loss: 1.2025 - val_dice_loss: 0.7859 - lr: 9.9901e-04
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 240/240 [==============================] - 47s 194ms/step - loss: 0.8969 - dice_loss: 0.7006 - val_loss: 1.0015 - val_dice_loss: 0.7813 - lr: 9.9606e-04
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 240/240 [==============================] - 46s 190ms/step - loss: 0.8833 - dice_loss: 0.6899 - val_loss: 1.0901 - val_dice_loss: 0.7191 - lr: 9.9114e-04
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.8650 - dice_loss: 0.6751 - val_loss: 0.8843 - val_dice_loss: 0.6937 - lr: 9.8429e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 240/240 [==============================] - 46s 190ms/step - loss: 0.8213 - dice_loss: 0.6416 - val_loss: 1.3176 - val_dice_loss: 0.7328 - lr: 9.7553e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.7796 - dice_loss: 0.6078 - val_loss: 0.8035 - val_dice_loss: 0.6179 - lr: 9.6489e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.7244 - dice_loss: 0.5643 - val_loss: 0.8167 - val_dice_loss: 0.6673 - lr: 9.5241e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.6480 - dice_loss: 0.5030 - val_loss: 0.7367 - val_dice_loss: 0.5429 - lr: 9.3815e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.6235 - dice_loss: 0.4849 - val_loss: 0.7100 - val_dice_loss: 0.5629 - lr: 9.2216e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.5505 - dice_loss: 0.4246 - val_loss: 0.7246 - val_dice_loss: 0.5725 - lr: 9.0451e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.5021 - dice_loss: 0.3865 - val_loss: 0.5500 - val_dice_loss: 0.4341 - lr: 8.8526e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.4279 - dice_loss: 0.3282 - val_loss: 0.5126 - val_dice_loss: 0.4058 - lr: 8.6448e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.3809 - dice_loss: 0.2914 - val_loss: 0.4946 - val_dice_loss: 0.3746 - lr: 8.4227e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.3571 - dice_loss: 0.2723 - val_loss: 0.4011 - val_dice_loss: 0.3059 - lr: 8.1871e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.3271 - dice_loss: 0.2472 - val_loss: 0.5156 - val_dice_loss: 0.4156 - lr: 7.9389e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.3129 - dice_loss: 0.2365 - val_loss: 0.3044 - val_dice_loss: 0.2358 - lr: 7.6791e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.2717 - dice_loss: 0.2049 - val_loss: 0.2618 - val_dice_loss: 0.2013 - lr: 7.4088e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.2610 - dice_loss: 0.1968 - val_loss: 0.4847 - val_dice_loss: 0.3910 - lr: 7.1289e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.2440 - dice_loss: 0.1843 - val_loss: 0.3016 - val_dice_loss: 0.2301 - lr: 6.8406e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.2151 - dice_loss: 0.1612 - val_loss: 0.3146 - val_dice_loss: 0.2420 - lr: 6.5451e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.2272 - dice_loss: 0.1713 - val_loss: 0.2763 - val_dice_loss: 0.2148 - lr: 6.2435e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.1929 - dice_loss: 0.1450 - val_loss: 0.2536 - val_dice_loss: 0.1983 - lr: 5.9369e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.2061 - dice_loss: 0.1558 - val_loss: 0.2218 - val_dice_loss: 0.1686 - lr: 5.6267e-04
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1763 - dice_loss: 0.1311 - val_loss: 0.2623 - val_dice_loss: 0.2018 - lr: 5.3140e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1702 - dice_loss: 0.1279 - val_loss: 0.2507 - val_dice_loss: 0.1935 - lr: 5.0000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1681 - dice_loss: 0.1264 - val_loss: 0.2279 - val_dice_loss: 0.1786 - lr: 4.6860e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1631 - dice_loss: 0.1240 - val_loss: 0.3116 - val_dice_loss: 0.2474 - lr: 4.3733e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.1453 - dice_loss: 0.1092 - val_loss: 0.2151 - val_dice_loss: 0.1702 - lr: 4.0631e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 240/240 [==============================] - 48s 200ms/step - loss: 0.1321 - dice_loss: 0.0989 - val_loss: 0.1772 - val_dice_loss: 0.1354 - lr: 3.7566e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 240/240 [==============================] - 46s 193ms/step - loss: 0.1354 - dice_loss: 0.1025 - val_loss: 0.2880 - val_dice_loss: 0.2273 - lr: 3.4549e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.1303 - dice_loss: 0.0985 - val_loss: 0.1729 - val_dice_loss: 0.1345 - lr: 3.1594e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1177 - dice_loss: 0.0881 - val_loss: 0.2021 - val_dice_loss: 0.1589 - lr: 2.8711e-04
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1138 - dice_loss: 0.0858 - val_loss: 0.2037 - val_dice_loss: 0.1572 - lr: 2.5912e-04
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.1099 - dice_loss: 0.0828 - val_loss: 0.1664 - val_dice_loss: 0.1272 - lr: 2.3209e-04
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.1038 - dice_loss: 0.0783 - val_loss: 0.1754 - val_dice_loss: 0.1385 - lr: 2.0611e-04
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 240/240 [==============================] - 46s 192ms/step - loss: 0.1005 - dice_loss: 0.0762 - val_loss: 0.1931 - val_dice_loss: 0.1484 - lr: 1.8129e-04
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.0940 - dice_loss: 0.0703 - val_loss: 0.1568 - val_dice_loss: 0.1219 - lr: 1.5773e-04
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.0957 - dice_loss: 0.0720 - val_loss: 0.1471 - val_dice_loss: 0.1147 - lr: 1.3552e-04
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0903 - dice_loss: 0.0680 - val_loss: 0.1637 - val_dice_loss: 0.1261 - lr: 1.1474e-04
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.0879 - dice_loss: 0.0663 - val_loss: 0.1256 - val_dice_loss: 0.0976 - lr: 9.5492e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0887 - dice_loss: 0.0671 - val_loss: 0.1334 - val_dice_loss: 0.1035 - lr: 7.7836e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0841 - dice_loss: 0.0629 - val_loss: 0.1281 - val_dice_loss: 0.0998 - lr: 6.1847e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0848 - dice_loss: 0.0647 - val_loss: 0.1273 - val_dice_loss: 0.0987 - lr: 4.7586e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0823 - dice_loss: 0.0618 - val_loss: 0.1259 - val_dice_loss: 0.0982 - lr: 3.5112e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0774 - dice_loss: 0.0580 - val_loss: 0.1256 - val_dice_loss: 0.0977 - lr: 2.4472e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.0786 - dice_loss: 0.0594 - val_loss: 0.1228 - val_dice_loss: 0.0950 - lr: 1.5708e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 240/240 [==============================] - 47s 195ms/step - loss: 0.0777 - dice_loss: 0.0585 - val_loss: 0.1221 - val_dice_loss: 0.0944 - lr: 8.8564e-06
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 240/240 [==============================] - 47s 196ms/step - loss: 0.0827 - dice_loss: 0.0630 - val_loss: 0.1214 - val_dice_loss: 0.0941 - lr: 3.9426e-06
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.0760 - dice_loss: 0.0565 - val_loss: 0.1233 - val_dice_loss: 0.0956 - lr: 9.8664e-07

# %%
# print sample image after training
print_images(model = unet_model)

# %%
# restoring the latest checkpoint in checkpoint_dir
unet_model.load_weights(checkpoint_dir_unet)

# %%
mean = []

for images, labels in test_dataset:
    predictions = unet_model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.8950820607993388

# %%
print_images(model = unet_model)

# %% [markdown]
# ## Step3. VGG16

# %%
vgg16 = tf.keras.applications.VGG16(input_shape=img_shape,
                                         include_top=False,
                                         weights='imagenet')
layer_outputs = [layer.output for layer in vgg16.layers]
layer_outputs
# Out:
# [<tf.Tensor 'input_1:0' shape=(None, 256, 256, 3) dtype=float32>,
#  <tf.Tensor 'block1_conv1/Identity:0' shape=(None, 256, 256, 64) dtype=float32>,
#  <tf.Tensor 'block1_conv2/Identity:0' shape=(None, 256, 256, 64) dtype=float32>,
#  <tf.Tensor 'block1_pool/Identity:0' shape=(None, 128, 128, 64) dtype=float32>,
#  <tf.Tensor 'block2_conv1/Identity:0' shape=(None, 128, 128, 128) dtype=float32>,
#  <tf.Tensor 'block2_conv2/Identity:0' shape=(None, 128, 128, 128) dtype=float32>,
#  <tf.Tensor 'block2_pool/Identity:0' shape=(None, 64, 64, 128) dtype=float32>,
#  <tf.Tensor 'block3_conv1/Identity:0' shape=(None, 64, 64, 256) dtype=float32>,
#  <tf.Tensor 'block3_conv2/Identity:0' shape=(None, 64, 64, 256) dtype=float32>,
#  <tf.Tensor 'block3_conv3/Identity:0' shape=(None, 64, 64, 256) dtype=float32>,
#  <tf.Tensor 'block3_pool/Identity:0' shape=(None, 32, 32, 256) dtype=float32>,
#  <tf.Tensor 'block4_conv1/Identity:0' shape=(None, 32, 32, 512) dtype=float32>,
#  <tf.Tensor 'block4_conv2/Identity:0' shape=(None, 32, 32, 512) dtype=float32>,
#  <tf.Tensor 'block4_conv3/Identity:0' shape=(None, 32, 32, 512) dtype=float32>,
#  <tf.Tensor 'block4_pool/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv1/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv2/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv3/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_pool/Identity:0' shape=(None, 8, 8, 512) dtype=float32>]

# %%
vgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
class Vgg16UNet(tf.keras.Model):
    def __init__(self):
        super(Vgg16UNet, self).__init__()
        self.vgg16 = tf.keras.applications.VGG16(input_shape=img_shape,
                                         include_top=False,
                                         weights='imagenet')
        layer_outputs = [layer.output for layer in self.vgg16.layers]
        self.vgg16_act = models.Model(inputs=self.vgg16.input, 
                                      outputs=[layer_outputs[2], 
                                               layer_outputs[5], 
                                               layer_outputs[9], 
                                               layer_outputs[13], 
                                               layer_outputs[17]])
        
        """
        <tf.Tensor 'input_1:0' shape=(None, 256, 256, 3) dtype=float32>,
        <tf.Tensor 'block1_conv1/Identity:0' shape=(None, 256, 256, 64) dtype=float32>,
        <tf.Tensor 'block1_conv2/Identity:0' shape=(None, 256, 256, 64) dtype=float32>, #2
        <tf.Tensor 'block1_pool/Identity:0' shape=(None, 128, 128, 64) dtype=float32>,
        <tf.Tensor 'block2_conv1/Identity:0' shape=(None, 128, 128, 128) dtype=float32>,
        <tf.Tensor 'block2_conv2/Identity:0' shape=(None, 128, 128, 128) dtype=float32>, #5
        <tf.Tensor 'block2_pool/Identity:0' shape=(None, 64, 64, 128) dtype=float32>,
        <tf.Tensor 'block3_conv1/Identity:0' shape=(None, 64, 64, 256) dtype=float32>,
        <tf.Tensor 'block3_conv2/Identity:0' shape=(None, 64, 64, 256) dtype=float32>,
        <tf.Tensor 'block3_conv3/Identity:0' shape=(None, 64, 64, 256) dtype=float32>, #9
        <tf.Tensor 'block3_pool/Identity:0' shape=(None, 32, 32, 256) dtype=float32>,
        <tf.Tensor 'block4_conv1/Identity:0' shape=(None, 32, 32, 512) dtype=float32>,
        <tf.Tensor 'block4_conv2/Identity:0' shape=(None, 32, 32, 512) dtype=float32>,
        <tf.Tensor 'block4_conv3/Identity:0' shape=(None, 32, 32, 512) dtype=float32>, #13
        <tf.Tensor 'block4_pool/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
        <tf.Tensor 'block5_conv1/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
        <tf.Tensor 'block5_conv2/Identity:0' shape=(None, 16, 16, 512) dtype=float32>,
        <tf.Tensor 'block5_conv3/Identity:0' shape=(None, 16, 16, 512) dtype=float32>, #17
        <tf.Tensor 'block5_pool/Identity:0' shape=(None, 8, 8, 512) dtype=float32>
        
        """


        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):

        encoder1, encoder2, encoder3, encoder4, center = self.vgg16_act(inputs) 

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)
        
        outputs = self.output_conv(decoder1)

        return outputs

# %%
vgg_model = Vgg16UNet()

# %%
optimizer_vgg = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
checkpoint_dir_vgg =os.path.join(DATASET_PATH,'train_ckpt/vgg_model')

# %%
vgg_model.compile(optimizer=optimizer_vgg, loss=bce_dice_loss, metrics=[dice_loss])
predictions = vgg_model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (2, 256, 256, 1)

# %%
# vgg_model.summary()

# %%
if not os.path.isdir(checkpoint_dir_vgg):
    os.makedirs(checkpoint_dir_vgg)

cp_callback_vgg = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir_vgg,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay_vgg = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback_vgg = tf.keras.callbacks.LearningRateScheduler(cos_decay_vgg, verbose=1)

# %%
history_vgg = vgg_model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback_vgg, lr_callback_vgg]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.8832 - dice_loss: 0.6691 - val_loss: 6.1650 - val_dice_loss: 0.8885 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.7615 - dice_loss: 0.5914 - val_loss: 0.8759 - val_dice_loss: 0.6835 - lr: 9.9901e-04
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.7112 - dice_loss: 0.5511 - val_loss: 0.7885 - val_dice_loss: 0.5879 - lr: 9.9606e-04
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.6803 - dice_loss: 0.5278 - val_loss: 0.8624 - val_dice_loss: 0.6265 - lr: 9.9114e-04
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.6352 - dice_loss: 0.4933 - val_loss: 0.7470 - val_dice_loss: 0.5938 - lr: 9.8429e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.5908 - dice_loss: 0.4572 - val_loss: 0.8040 - val_dice_loss: 0.5811 - lr: 9.7553e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.5423 - dice_loss: 0.4188 - val_loss: 1.0397 - val_dice_loss: 0.6303 - lr: 9.6489e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.5279 - dice_loss: 0.4077 - val_loss: 0.9755 - val_dice_loss: 0.8053 - lr: 9.5241e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.4601 - dice_loss: 0.3544 - val_loss: 0.4988 - val_dice_loss: 0.4012 - lr: 9.3815e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.4275 - dice_loss: 0.3273 - val_loss: 0.4892 - val_dice_loss: 0.3890 - lr: 9.2216e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.3568 - dice_loss: 0.2731 - val_loss: 0.5317 - val_dice_loss: 0.4241 - lr: 9.0451e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.3160 - dice_loss: 0.2429 - val_loss: 0.4099 - val_dice_loss: 0.3124 - lr: 8.8526e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.2926 - dice_loss: 0.2255 - val_loss: 0.4351 - val_dice_loss: 0.3415 - lr: 8.6448e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.2754 - dice_loss: 0.2105 - val_loss: 0.4344 - val_dice_loss: 0.3459 - lr: 8.4227e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.2430 - dice_loss: 0.1838 - val_loss: 0.3257 - val_dice_loss: 0.2458 - lr: 8.1871e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.2213 - dice_loss: 0.1667 - val_loss: 0.4529 - val_dice_loss: 0.3547 - lr: 7.9389e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.1912 - dice_loss: 0.1430 - val_loss: 0.3037 - val_dice_loss: 0.2256 - lr: 7.6791e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.1848 - dice_loss: 0.1407 - val_loss: 0.2926 - val_dice_loss: 0.2284 - lr: 7.4088e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.1548 - dice_loss: 0.1149 - val_loss: 0.2087 - val_dice_loss: 0.1611 - lr: 7.1289e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.1497 - dice_loss: 0.1125 - val_loss: 0.2054 - val_dice_loss: 0.1599 - lr: 6.8406e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1446 - dice_loss: 0.1088 - val_loss: 0.2088 - val_dice_loss: 0.1578 - lr: 6.5451e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1440 - dice_loss: 0.1086 - val_loss: 0.2423 - val_dice_loss: 0.1890 - lr: 6.2435e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.1259 - dice_loss: 0.0947 - val_loss: 0.1483 - val_dice_loss: 0.1133 - lr: 5.9369e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.1188 - dice_loss: 0.0881 - val_loss: 0.1358 - val_dice_loss: 0.1048 - lr: 5.6267e-04
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1032 - dice_loss: 0.0773 - val_loss: 0.1698 - val_dice_loss: 0.1282 - lr: 5.3140e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 240/240 [==============================] - 30s 126ms/step - loss: 0.1027 - dice_loss: 0.0767 - val_loss: 0.1430 - val_dice_loss: 0.1080 - lr: 5.0000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.0879 - dice_loss: 0.0660 - val_loss: 0.1479 - val_dice_loss: 0.1150 - lr: 4.6860e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.0851 - dice_loss: 0.0639 - val_loss: 0.1301 - val_dice_loss: 0.1015 - lr: 4.3733e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.0901 - dice_loss: 0.0673 - val_loss: 0.1241 - val_dice_loss: 0.0932 - lr: 4.0631e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0747 - dice_loss: 0.0562 - val_loss: 0.1314 - val_dice_loss: 0.1014 - lr: 3.7566e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0742 - dice_loss: 0.0565 - val_loss: 0.1986 - val_dice_loss: 0.1499 - lr: 3.4549e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0776 - dice_loss: 0.0585 - val_loss: 0.1457 - val_dice_loss: 0.1091 - lr: 3.1594e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.0749 - dice_loss: 0.0567 - val_loss: 0.1154 - val_dice_loss: 0.0886 - lr: 2.8711e-04
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.0653 - dice_loss: 0.0490 - val_loss: 0.0885 - val_dice_loss: 0.0674 - lr: 2.5912e-04
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0580 - dice_loss: 0.0433 - val_loss: 0.0967 - val_dice_loss: 0.0745 - lr: 2.3209e-04
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0576 - dice_loss: 0.0430 - val_loss: 0.1006 - val_dice_loss: 0.0773 - lr: 2.0611e-04
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0604 - dice_loss: 0.0459 - val_loss: 0.0922 - val_dice_loss: 0.0710 - lr: 1.8129e-04
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0572 - dice_loss: 0.0431 - val_loss: 0.1261 - val_dice_loss: 0.0933 - lr: 1.5773e-04
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0526 - dice_loss: 0.0394 - val_loss: 0.1055 - val_dice_loss: 0.0804 - lr: 1.3552e-04
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0529 - dice_loss: 0.0394 - val_loss: 0.1042 - val_dice_loss: 0.0796 - lr: 1.1474e-04
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0510 - dice_loss: 0.0379 - val_loss: 0.0955 - val_dice_loss: 0.0725 - lr: 9.5492e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0495 - dice_loss: 0.0370 - val_loss: 0.0973 - val_dice_loss: 0.0737 - lr: 7.7836e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0493 - dice_loss: 0.0370 - val_loss: 0.0943 - val_dice_loss: 0.0715 - lr: 6.1847e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0477 - dice_loss: 0.0353 - val_loss: 0.0989 - val_dice_loss: 0.0750 - lr: 4.7586e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0488 - dice_loss: 0.0367 - val_loss: 0.0983 - val_dice_loss: 0.0742 - lr: 3.5112e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0480 - dice_loss: 0.0359 - val_loss: 0.0958 - val_dice_loss: 0.0728 - lr: 2.4472e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0465 - dice_loss: 0.0346 - val_loss: 0.0956 - val_dice_loss: 0.0725 - lr: 1.5708e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0453 - dice_loss: 0.0336 - val_loss: 0.0949 - val_dice_loss: 0.0720 - lr: 8.8564e-06
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0462 - dice_loss: 0.0343 - val_loss: 0.0955 - val_dice_loss: 0.0723 - lr: 3.9426e-06
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.0457 - dice_loss: 0.0341 - val_loss: 0.0955 - val_dice_loss: 0.0723 - lr: 9.8664e-07

# %%
# print sample image after training
print_images(model = vgg_model)

# %%
# restoring the latest checkpoint in checkpoint_dir
vgg_model.load_weights(checkpoint_dir_vgg)

# %%
mean = []

for images, labels in test_dataset:
    predictions = vgg_model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.918606502370982

# %%
print_images(model = vgg_model)

# %% [markdown]
# ## Step4. Encoder-Decoder

# %%
# inputs: [batch_size, 256, 256, 3]
encoder = tf.keras.Sequential(name='encoder')

# conv-batchnorm-activation-maxpool
encoder.add(layers.Conv2D(64, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(64, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv1: [batch_size, 128, 128, 64]

encoder.add(layers.Conv2D(128, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(128, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv2: [batch_size, 64, 64, 128]

encoder.add(layers.Conv2D(256, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(256, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv3: [batch_size, 32, 32, 256]

encoder.add(layers.Conv2D(512, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(512, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv4-outputs: [batch_size, 16, 16, 512]

# %%
# Encoder 제대로 만들어졌는지 확인

bottleneck = encoder(tf.random.normal([batch_size, 256, 256, 3]))
print(bottleneck.shape)   # (batch_size, 16, 16, 512) 이 나오는지 확인
# Out:
# (2, 16, 16, 512)

# %%
# inputs: [batch_size, 16, 16, 512]
decoder = tf.keras.Sequential(name='decoder')

# conv_transpose-batchnorm-activation
decoder.add(layers.Conv2DTranspose(256, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose1: [batch_size, 32, 32, 256]
decoder.add(layers.Conv2D(256, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(128, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose2: [batch_size, 64, 64, 128]
decoder.add(layers.Conv2D(128, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose3: [batch_size, 128, 128, 64]
decoder.add(layers.Conv2D(64, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(32, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv transpose4-outputs: [batch_size, 256, 256, 32]
decoder.add(layers.Conv2D(32, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(1, 1, strides=1, padding='same', activation='sigmoid'))

# %%
# decoder 제대로 만들어졌는지 확인

predictions = decoder(bottleneck)
print(predictions.shape)    # (batch_size, 256, 256, 1) 이 나오는지 확인
# Out:
# (2, 256, 256, 1)

# %%
ed_model = tf.keras.Sequential()

ed_model.add(encoder)
ed_model.add(decoder)

# %%
optimizer_ed = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
checkpoint_dir_ed =os.path.join(DATASET_PATH,'train_ckpt/ed_model')

# %%
ed_model.compile(optimizer=optimizer_ed, loss=bce_dice_loss, metrics=[dice_loss])
predictions = ed_model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (2, 256, 256, 1)

# %%
ed_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Sequential)         multiple                  4693056
# _________________________________________________________________
# decoder (Sequential)         multiple                  2354913
# =================================================================
# Total params: 7,047,969
# Trainable params: 7,042,209
# Non-trainable params: 5,760
# _________________________________________________________________

# %%
if not os.path.isdir(checkpoint_dir_ed):
    os.makedirs(checkpoint_dir_ed)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir_ed,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
history_ed = ed_model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.9759 - dice_loss: 0.7281 - val_loss: 2.2215 - val_dice_loss: 0.8427 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.8121 - dice_loss: 0.6285 - val_loss: 5.3601 - val_dice_loss: 0.8303 - lr: 9.9901e-04
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.6907 - dice_loss: 0.5333 - val_loss: 0.8673 - val_dice_loss: 0.7111 - lr: 9.9606e-04
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.6255 - dice_loss: 0.4814 - val_loss: 0.6840 - val_dice_loss: 0.5481 - lr: 9.9114e-04
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.5319 - dice_loss: 0.4070 - val_loss: 0.6520 - val_dice_loss: 0.5156 - lr: 9.8429e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.4584 - dice_loss: 0.3481 - val_loss: 0.5354 - val_dice_loss: 0.3840 - lr: 9.7553e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.4243 - dice_loss: 0.3223 - val_loss: 0.4280 - val_dice_loss: 0.3343 - lr: 9.6489e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.3752 - dice_loss: 0.2836 - val_loss: 0.4359 - val_dice_loss: 0.3258 - lr: 9.5241e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.3659 - dice_loss: 0.2779 - val_loss: 0.5209 - val_dice_loss: 0.4066 - lr: 9.3815e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.3347 - dice_loss: 0.2521 - val_loss: 0.3872 - val_dice_loss: 0.2940 - lr: 9.2216e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.3108 - dice_loss: 0.2348 - val_loss: 0.3254 - val_dice_loss: 0.2502 - lr: 9.0451e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.2924 - dice_loss: 0.2204 - val_loss: 0.5367 - val_dice_loss: 0.3861 - lr: 8.8526e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.2750 - dice_loss: 0.2071 - val_loss: 0.4581 - val_dice_loss: 0.3207 - lr: 8.6448e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.2551 - dice_loss: 0.1927 - val_loss: 0.3545 - val_dice_loss: 0.2800 - lr: 8.4227e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.2371 - dice_loss: 0.1781 - val_loss: 0.4028 - val_dice_loss: 0.3169 - lr: 8.1871e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.2105 - dice_loss: 0.1568 - val_loss: 0.3743 - val_dice_loss: 0.2901 - lr: 7.9389e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.2122 - dice_loss: 0.1591 - val_loss: 0.2550 - val_dice_loss: 0.1938 - lr: 7.6791e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1942 - dice_loss: 0.1444 - val_loss: 0.3153 - val_dice_loss: 0.2474 - lr: 7.4088e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.1864 - dice_loss: 0.1398 - val_loss: 0.2477 - val_dice_loss: 0.1844 - lr: 7.1289e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.1786 - dice_loss: 0.1333 - val_loss: 0.1889 - val_dice_loss: 0.1427 - lr: 6.8406e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1643 - dice_loss: 0.1236 - val_loss: 0.2543 - val_dice_loss: 0.1946 - lr: 6.5451e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1600 - dice_loss: 0.1195 - val_loss: 0.2139 - val_dice_loss: 0.1634 - lr: 6.2435e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1497 - dice_loss: 0.1125 - val_loss: 0.2609 - val_dice_loss: 0.2019 - lr: 5.9369e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.1488 - dice_loss: 0.1115 - val_loss: 0.1884 - val_dice_loss: 0.1456 - lr: 5.6267e-04
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.1391 - dice_loss: 0.1045 - val_loss: 0.1606 - val_dice_loss: 0.1220 - lr: 5.3140e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1173 - dice_loss: 0.0876 - val_loss: 0.1956 - val_dice_loss: 0.1483 - lr: 5.0000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1066 - dice_loss: 0.0792 - val_loss: 0.1701 - val_dice_loss: 0.1279 - lr: 4.6860e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1121 - dice_loss: 0.0837 - val_loss: 0.1661 - val_dice_loss: 0.1262 - lr: 4.3733e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1020 - dice_loss: 0.0768 - val_loss: 0.1658 - val_dice_loss: 0.1276 - lr: 4.0631e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.1036 - dice_loss: 0.0771 - val_loss: 0.1872 - val_dice_loss: 0.1464 - lr: 3.7566e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0937 - dice_loss: 0.0700 - val_loss: 0.1447 - val_dice_loss: 0.1091 - lr: 3.4549e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0851 - dice_loss: 0.0635 - val_loss: 0.1214 - val_dice_loss: 0.0920 - lr: 3.1594e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0842 - dice_loss: 0.0630 - val_loss: 0.1418 - val_dice_loss: 0.1085 - lr: 2.8711e-04
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0915 - dice_loss: 0.0693 - val_loss: 0.1477 - val_dice_loss: 0.1120 - lr: 2.5912e-04
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0827 - dice_loss: 0.0628 - val_loss: 0.1330 - val_dice_loss: 0.1027 - lr: 2.3209e-04
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0761 - dice_loss: 0.0571 - val_loss: 0.1309 - val_dice_loss: 0.0994 - lr: 2.0611e-04
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0734 - dice_loss: 0.0543 - val_loss: 0.1211 - val_dice_loss: 0.0906 - lr: 1.8129e-04
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0714 - dice_loss: 0.0536 - val_loss: 0.1207 - val_dice_loss: 0.0915 - lr: 1.5773e-04
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0687 - dice_loss: 0.0513 - val_loss: 0.1214 - val_dice_loss: 0.0922 - lr: 1.3552e-04
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0661 - dice_loss: 0.0496 - val_loss: 0.1095 - val_dice_loss: 0.0827 - lr: 1.1474e-04
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0666 - dice_loss: 0.0497 - val_loss: 0.1084 - val_dice_loss: 0.0823 - lr: 9.5492e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0682 - dice_loss: 0.0516 - val_loss: 0.1169 - val_dice_loss: 0.0881 - lr: 7.7836e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0651 - dice_loss: 0.0489 - val_loss: 0.1061 - val_dice_loss: 0.0801 - lr: 6.1847e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0616 - dice_loss: 0.0459 - val_loss: 0.1100 - val_dice_loss: 0.0827 - lr: 4.7586e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0620 - dice_loss: 0.0466 - val_loss: 0.1090 - val_dice_loss: 0.0818 - lr: 3.5112e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0608 - dice_loss: 0.0454 - val_loss: 0.1100 - val_dice_loss: 0.0826 - lr: 2.4472e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0603 - dice_loss: 0.0454 - val_loss: 0.1069 - val_dice_loss: 0.0802 - lr: 1.5708e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0611 - dice_loss: 0.0460 - val_loss: 0.1061 - val_dice_loss: 0.0796 - lr: 8.8564e-06
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0613 - dice_loss: 0.0461 - val_loss: 0.1050 - val_dice_loss: 0.0789 - lr: 3.9426e-06
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0620 - dice_loss: 0.0468 - val_loss: 0.1058 - val_dice_loss: 0.0796 - lr: 9.8664e-07

# %%
# print sample image after training
print_images(model = ed_model)

# %%
# restoring the latest checkpoint in checkpoint_dir
ed_model.load_weights(checkpoint_dir_ed)

# %%
mean = []

for images, labels in test_dataset:
    predictions = ed_model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.9081379964112725

# %%
print_images(model = ed_model)

# %%
dice_loss = history_ed.history['dice_loss']
loss = history_ed.history['loss']
val_dice_loss = history_ed.history['val_dice_loss']
val_loss = history_ed.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %% [markdown]
# ## Step5. ResNet

# %% [markdown]
# ## 총평

# %% [markdown]
# ### 발생한 문제
# VGG의 모델을 summary()함수를 통해 불러올때 에러가 발생한다.
# VGG-UNet순으로 동작시 callback함수가 list를 불러올 수 없다는 에러가 발생한다.
